# %%
''''
1 supervised learning: dataset that is labeled, predict, linear regression
decision tree, support vector machine, neural networks (Supervised Learning algorithms)
2. Unsupervised learning: deals with unlableled data. clustering algorithms to group 
data together, k-means clustering, hierarchical clustering, PCA(Principal Component Analysis)
3. Reinforcement Learning:

# Problem Formulation!
Define the problem! Classification task, regressiS, cLUSTERING, anomaly detection recommendation
2 Gather the data
3 Split the data
20, 80

Data Types:
3 categories of data!
1. Numerical data can be descrete(Integers) or continuous(infinite values)
2. categorical data can be measured against each other
3. Ordinal data can not be measured against each other
'''

# %%
# importing the required modules
import numpy as np #for linear regression
import pandas as pd #for processing, csv file reading
import matplotlib.pyplot as plt #for plotting / data visualization
import seaborn as sns #for plotting
# %matplotlib inline

# ml for regression
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# control dispaly (optional)
pd.options.display.max_columns = 50
sns.set(style="darkgrid", rc={'axes.facecolor' : '#CAF1DE'})
# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# load / read the dataset
df = pd.read_csv('heart_disease.csv')
df.head()

# %%
'''
_summary_
cp = chest pain
trestbps = resting blood pressure
chol = cholesterol
fbs = fasting blood sugar
restecg = resting electrocardiography
exang = exercise induced agina
oldpeak = ST depression induced
slope = slop of the peak exercise
ca = number of major vessels
thal = normal, fexied defect, reversible defect
target 0-dont have 1-have

'''

# %%
# show people with heart diseases 
# use the column target to get the numbers
df.target.value_counts()

# %%
# show percentage of male and female
count_female = len(df[df.sex == 0])
count_male = len(df[df.sex == 1])

# show the percentage of female patients 
print(f"Percentage os female patients: {round(count_female/(len(df.sex)) * 100 , 2)}%")
print(f"Percentage os male patients: {round(count_male/(len(df.sex)) * 100 , 2)}%")

count_male

# %%
# finding the mean of the data 
df.groupby('target').mean()

# %%
# plotting a bar graph showing heart disease frequency of age
pd.crosstab(df.age, df.target).plot(kind='bar', figsize=(20,6))
plt.title('Heart diseases Frequency for Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# # plotting a bar graph showing heart disease frequency of age
# pd.crosstab(df.sex, df.target).plot(kind='bar', figsize=(20,6), color=['#FF09AC', '#FFF09A'])
# plt.title('Heart diseases Frequency for Ages')
# plt.xlabel('sex (0 = Feamle, 1 = Male)')
# plt.legend(['Have Disease', 'Doesnt have'])
# plt.ylabel('Frequency')
# plt.show()

# %%
# Scatter plot 
age = df['age']
chol = df['chol']

# Create scatter plot
plt.scatter(age, chol, c=df['target'], cmap='coolwarm')
plt.xlabel('Age')
plt.ylabel('Cholesterol')
plt.title('Scatter Plot: Age vs Cholesterol')
plt.colorbar(label='Target')
plt.show()

# %%
# working with ML model Accuracy of different ML more\
# Create model for Logistic Regression
# Solve problem based on classification
# Create independent variables and dependent variables
#

# %%
# creating a model for logistic regression
y = df.target.values
x_data = df.drop(['target'], axis = 1)

# %%
# Normalizing the data ! split our data for training and testing
# 80% training and 20% testing

# normalize the data x = (X-Xmin)/ (Xmax-Xmin)
x = (x_data - np.min(x_data)) / (np.max(x_data) - (np.min(x_data)))
# Out:
#            age       sex        cp  trestbps      chol       fbs   restecg  \
# 0     0.092199  0.001773  0.000000  0.221631  0.375887  0.000000  0.001773
# 1     0.093972  0.001773  0.000000  0.248227  0.359929  0.001773  0.000000
# 2     0.124113  0.001773  0.000000  0.257092  0.308511  0.000000  0.001773
# 3     0.108156  0.001773  0.000000  0.262411  0.359929  0.000000  0.001773
# 4     0.109929  0.000000  0.000000  0.244681  0.521277  0.001773  0.001773
# ...        ...       ...       ...       ...       ...       ...       ...
# 1020  0.104610  0.001773  0.001773  0.248227  0.391844  0.000000  0.001773
# 1021  0.106383  0.001773  0.000000  0.221631  0.457447  0.000000  0.000000
# 1022  0.083333  0.001773  0.000000  0.195035  0.487589  0.000000  0.000000
# 1023  0.088652  0.000000  0.000000  0.195035  0.450355  0.000000  0.000000
# 1024  0.095745  0.001773  0.000000  0.212766  0.333333  0.000000  0.001773
#
#        thalach     exang   oldpeak     slope        ca      thal
# ...
